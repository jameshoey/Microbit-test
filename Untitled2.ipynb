# %% [markdown]
# <a href="https://colab.research.google.com/github/jameshoey/Microbit-test/blob/master/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip

# %% [markdown]
# text

# %%
df

# %% [markdown]
# gdf

# %%
dsg

# %% [markdown]
# fgd
